# %%
# CHANGE INFO TO RUN ON YOUR LOCAL
host = "127.0.0.1"
port = "5432"
# database = "MSDS691"
database = 'msds691'
user = "postgres"

# %%
import psycopg2
import pandas as pd
import numpy as np

conn = psycopg2.connect(host=host, port=port, database=database, user=user)
cur = conn.cursor()

# %%
def select_query(query):
    df = pd.read_sql_query(query, conn, coerce_float=False)
    df.replace([None], np.nan, inplace=True)

    return df

# %%
from IPython.core.display import display, HTML


def display_side_by_side(dfs: list, captions: list):
    """Display tables side by side to save vertical space
    Input:
        dfs: list of pandas.DataFrame
        captions: list of table captions
    """

    output = ""
    combined = dict(zip(captions, dfs))
    for caption, df in combined.items():
        output += df.style.set_table_attributes("style='display:inline'")\
                    .set_caption(caption)._repr_html_()
        output += "\xa0\xa0\xa0"
    display(HTML(output))

# %%
cur.execute(f'''DROP TABLE IF EXISTS names;''')
cur.execute(f'''DROP TABLE IF EXISTS transactions;''')

# %%
create = f'''

DROP TABLE IF EXISTS names;

CREATE TABLE names
(id INTEGER,
name VARCHAR,
PRIMARY KEY (id))
;

INSERT INTO names
VALUES
(1, 'Jon Smith'),
(2, 'Sarah Adams'),
(3, 'Maria Lopez')
;'''

cur.execute(create)
conn.commit()

create = f'''

DROP TABLE IF EXISTS transactions;

CREATE TABLE transactions
(id INTEGER,
 amount NUMERIC,
 PRIMARY KEY (id))
;

INSERT INTO transactions
VALUES
(1, 10),
(3, 20),
(7, 50)
;'''

cur.execute(create)
conn.commit()

# %%
query = f'''

SELECT *
FROM names

;'''
df_names = select_query(query)
df_names
# Out:
#    id         name
# 0   1    Jon Smith
# 1   2  Sarah Adams
# 2   3  Maria Lopez

# %%
query = f'''

SELECT *
FROM transactions

;'''
df_transactions = select_query(query)
df_transactions
# Out:
#    id amount
# 0   1     10
# 1   3     20
# 2   7     50

# %% [markdown]
# ### Inner Join

# %%
query = f'''

SELECT  names.id, names.name, transactions.amount
FROM names INNER JOIN transactions
    ON (names.id = transactions.id)

;'''
df_inner_join = select_query(query)
display_side_by_side([df_names, df_transactions, df_inner_join],
                     ['Left Table', 'Right Table', 'Inner Join Output'])
# Out:
# <style  type="text/css" >
# </style><table id="T_46f73_" style='display:inline'><caption>Left Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46f73_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_46f73_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_46f73_row0_col1" class="data row0 col1" >Jon Smith</td>
#             </tr>
#             <tr>
#                         <th id="T_46f73_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_46f73_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_46f73_row1_col1" class="data row1 col1" >Sarah Adams</td>
#             </tr>
#             <tr>
#                         <th id="T_46f73_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_46f73_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_46f73_row2_col1" class="data row2 col1" >Maria Lopez</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_f1fcb_" style='display:inline'><caption>Right Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1fcb_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1fcb_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f1fcb_row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f1fcb_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1fcb_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_f1fcb_row1_col1" class="data row1 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_f1fcb_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1fcb_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_f1fcb_row2_col1" class="data row2 col1" >50</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_68ab6_" style='display:inline'><caption>Inner Join Output</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68ab6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_68ab6_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_68ab6_row0_col1" class="data row0 col1" >Jon Smith</td>
#                         <td id="T_68ab6_row0_col2" class="data row0 col2" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_68ab6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_68ab6_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_68ab6_row1_col1" class="data row1 col1" >Maria Lopez</td>
#                         <td id="T_68ab6_row1_col2" class="data row1 col2" >20</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Left Join

# %%
query = f'''

SELECT  names.id, names.name, transactions.amount
FROM names LEFT JOIN transactions
    ON (names.id = transactions.id)

;'''
df_left_join = select_query(query)
display_side_by_side([df_names, df_transactions, df_left_join],
                     ['Left Table', 'Right Table', 'Left Join Output'])
# Out:
# <style  type="text/css" >
# </style><table id="T_df1af_" style='display:inline'><caption>Left Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df1af_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_df1af_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_df1af_row0_col1" class="data row0 col1" >Jon Smith</td>
#             </tr>
#             <tr>
#                         <th id="T_df1af_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_df1af_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_df1af_row1_col1" class="data row1 col1" >Sarah Adams</td>
#             </tr>
#             <tr>
#                         <th id="T_df1af_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_df1af_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_df1af_row2_col1" class="data row2 col1" >Maria Lopez</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_f83c6_" style='display:inline'><caption>Right Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f83c6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f83c6_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f83c6_row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f83c6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f83c6_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_f83c6_row1_col1" class="data row1 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_f83c6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f83c6_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_f83c6_row2_col1" class="data row2 col1" >50</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_c5d09_" style='display:inline'><caption>Left Join Output</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c5d09_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c5d09_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c5d09_row0_col1" class="data row0 col1" >Jon Smith</td>
#                         <td id="T_c5d09_row0_col2" class="data row0 col2" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_c5d09_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c5d09_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_c5d09_row1_col1" class="data row1 col1" >Sarah Adams</td>
#                         <td id="T_c5d09_row1_col2" class="data row1 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c5d09_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c5d09_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_c5d09_row2_col1" class="data row2 col1" >Maria Lopez</td>
#                         <td id="T_c5d09_row2_col2" class="data row2 col2" >20</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Right Join

# %%
query = f'''

SELECT  transactions.id, names.name, transactions.amount
FROM names RIGHT JOIN transactions
    ON (names.id = transactions.id)

;'''
df_right_join = select_query(query)
display_side_by_side([df_names, df_transactions, df_right_join],
                     ['Left Table', 'Right Table', 'Right Join Output'])
# Out:
# <style  type="text/css" >
# </style><table id="T_dfd20_" style='display:inline'><caption>Left Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfd20_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dfd20_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_dfd20_row0_col1" class="data row0 col1" >Jon Smith</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd20_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dfd20_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_dfd20_row1_col1" class="data row1 col1" >Sarah Adams</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd20_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dfd20_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_dfd20_row2_col1" class="data row2 col1" >Maria Lopez</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_8d2c9_" style='display:inline'><caption>Right Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d2c9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8d2c9_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8d2c9_row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_8d2c9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8d2c9_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_8d2c9_row1_col1" class="data row1 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_8d2c9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8d2c9_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_8d2c9_row2_col1" class="data row2 col1" >50</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_8c792_" style='display:inline'><caption>Right Join Output</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c792_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8c792_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8c792_row0_col1" class="data row0 col1" >Jon Smith</td>
#                         <td id="T_8c792_row0_col2" class="data row0 col2" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_8c792_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8c792_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_8c792_row1_col1" class="data row1 col1" >Maria Lopez</td>
#                         <td id="T_8c792_row1_col2" class="data row1 col2" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_8c792_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8c792_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_8c792_row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_8c792_row2_col2" class="data row2 col2" >50</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Full Join

# %%
query = f'''

SELECT COALESCE(names.id,transactions.id) as id,
       names.name, transactions.amount
FROM names FULL JOIN transactions
    ON (names.id = transactions.id)

;'''
df_full_join = select_query(query)
display_side_by_side([df_names, df_transactions, df_full_join],
                     ['Left Table', 'Right Table', 'Full Join Output'])
# Out:
# <style  type="text/css" >
# </style><table id="T_93690_" style='display:inline'><caption>Left Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93690_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_93690_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_93690_row0_col1" class="data row0 col1" >Jon Smith</td>
#             </tr>
#             <tr>
#                         <th id="T_93690_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_93690_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_93690_row1_col1" class="data row1 col1" >Sarah Adams</td>
#             </tr>
#             <tr>
#                         <th id="T_93690_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_93690_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_93690_row2_col1" class="data row2 col1" >Maria Lopez</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_64c3d_" style='display:inline'><caption>Right Table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64c3d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_64c3d_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_64c3d_row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_64c3d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_64c3d_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_64c3d_row1_col1" class="data row1 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_64c3d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_64c3d_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_64c3d_row2_col1" class="data row2 col1" >50</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b60a2_" style='display:inline'><caption>Full Join Output</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b60a2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b60a2_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b60a2_row0_col1" class="data row0 col1" >Jon Smith</td>
#                         <td id="T_b60a2_row0_col2" class="data row0 col2" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_b60a2_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b60a2_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_b60a2_row1_col1" class="data row1 col1" >Sarah Adams</td>
#                         <td id="T_b60a2_row1_col2" class="data row1 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b60a2_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b60a2_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_b60a2_row2_col1" class="data row2 col1" >Maria Lopez</td>
#                         <td id="T_b60a2_row2_col2" class="data row2 col2" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_b60a2_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b60a2_row3_col0" class="data row3 col0" >7</td>
#                         <td id="T_b60a2_row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_b60a2_row3_col2" class="data row3 col2" >50</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Cross Join

# %%
import pandas.io.sql as sqlio

# %%
query = f'''

SELECT *
FROM names CROSS JOIN transactions

;'''
# df_cross_join = select_query(query)
# display_side_by_side([df_names, df_transactions, df_cross_join],
# ['Left Table', 'Right Table', 'Cross Join Output'])
dat = sqlio.read_sql_query(query, conn)
dat
# Out:
#    id         name  id  amount
# 0   1    Jon Smith   1    10.0
# 1   1    Jon Smith   3    20.0
# 2   1    Jon Smith   7    50.0
# 3   2  Sarah Adams   1    10.0
# 4   2  Sarah Adams   3    20.0
# 5   2  Sarah Adams   7    50.0
# 6   3  Maria Lopez   1    10.0
# 7   3  Maria Lopez   3    20.0
# 8   3  Maria Lopez   7    50.0

# %% [markdown]
# ### Add dob_table

# %%
create = f'''
DROP TABLE IF EXISTS dob_table;


CREATE TABLE dob_table
(id INTEGER,
 dob date,
 PRIMARY KEY (id));

INSERT INTO dob_table
VALUES
(1, '1982-09-29'),
(3, '1996-02-16')
;'''

cur.execute(create)
conn.commit()

# %% [markdown]
# ### Select all dob_table

# %%
query = f'''

SELECT *
FROM dob_table

;'''
df_dob = select_query(query)
df_dob
# Out:
#    id         dob
# 0   1  1982-09-29
# 1   3  1996-02-16

# %% [markdown]
# ### Join 3 tables

# %%
query = f'''

SELECT  names.id, names.name, transactions.amount, dob_table.dob
FROM names
    INNER JOIN transactions
        ON (names.id = transactions.id)
    INNER JOIN dob_table
        ON (names.id = dob_table.id)

;'''
df_three_tables = select_query(query)
display_side_by_side([df_names, df_transactions, df_dob, df_three_tables],
                     ['names', 'transactions', 'dob', 'all three tables'])
# Out:
# <style  type="text/css" >
# </style><table id="T_30095_" style='display:inline'><caption>names</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30095_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_30095_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_30095_row0_col1" class="data row0 col1" >Jon Smith</td>
#             </tr>
#             <tr>
#                         <th id="T_30095_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_30095_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_30095_row1_col1" class="data row1 col1" >Sarah Adams</td>
#             </tr>
#             <tr>
#                         <th id="T_30095_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_30095_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_30095_row2_col1" class="data row2 col1" >Maria Lopez</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_ff5d9_" style='display:inline'><caption>transactions</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff5d9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ff5d9_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ff5d9_row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_ff5d9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ff5d9_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_ff5d9_row1_col1" class="data row1 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_ff5d9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ff5d9_row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_ff5d9_row2_col1" class="data row2 col1" >50</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_59d03_" style='display:inline'><caption>dob</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >dob</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_59d03_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_59d03_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_59d03_row0_col1" class="data row0 col1" >1982-09-29</td>
#             </tr>
#             <tr>
#                         <th id="T_59d03_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_59d03_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_59d03_row1_col1" class="data row1 col1" >1996-02-16</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_ca7ce_" style='display:inline'><caption>all three tables</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >amount</th>        <th class="col_heading level0 col3" >dob</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca7ce_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ca7ce_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ca7ce_row0_col1" class="data row0 col1" >Jon Smith</td>
#                         <td id="T_ca7ce_row0_col2" class="data row0 col2" >10</td>
#                         <td id="T_ca7ce_row0_col3" class="data row0 col3" >1982-09-29</td>
#             </tr>
#             <tr>
#                         <th id="T_ca7ce_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ca7ce_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_ca7ce_row1_col1" class="data row1 col1" >Maria Lopez</td>
#                         <td id="T_ca7ce_row1_col2" class="data row1 col2" >20</td>
#                         <td id="T_ca7ce_row1_col3" class="data row1 col3" >1996-02-16</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### One-to-many Join

# %%
create = f'''

DROP TABLE IF EXISTS long_transactions;

CREATE TABLE long_transactions
(id INTEGER,
amount NUMERIC);

INSERT INTO long_transactions
VALUES
(1, 10),
(1, 50),
(2, 45),
(3, 20),
(3, 70),
(7, 50)
;'''
cur.execute(create)
conn.commit()

# %% [markdown]
# ### Select all from long_transactions

# %%
query = f'''

SELECT  *
FROM long_transactions

;'''
df_long_tran = select_query(query)
df_long_tran
# Out:
#    id amount
# 0   1     10
# 1   1     50
# 2   2     45
# 3   3     20
# 4   3     70
# 5   7     50

# %% [markdown]
# ### One-to-many

# %%
query = f'''

SELECT  names.id, names.name, long_transactions.amount
FROM names LEFT JOIN long_transactions
    ON (names.id = long_transactions.id)

;'''
df_one_many = select_query(query)
display_side_by_side([df_names, df_long_tran, df_one_many],
                     ['names', 'transactions', 'One-to-many'])
# Out:
# <style  type="text/css" >
# </style><table id="T_7a9d5_" style='display:inline'><caption>names</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a9d5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a9d5_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_7a9d5_row0_col1" class="data row0 col1" >Jon Smith</td>
#             </tr>
#             <tr>
#                         <th id="T_7a9d5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7a9d5_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_7a9d5_row1_col1" class="data row1 col1" >Sarah Adams</td>
#             </tr>
#             <tr>
#                         <th id="T_7a9d5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7a9d5_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_7a9d5_row2_col1" class="data row2 col1" >Maria Lopez</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_9a83c_" style='display:inline'><caption>transactions</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a83c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9a83c_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9a83c_row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_9a83c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9a83c_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_9a83c_row1_col1" class="data row1 col1" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_9a83c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9a83c_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_9a83c_row2_col1" class="data row2 col1" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_9a83c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9a83c_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_9a83c_row3_col1" class="data row3 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_9a83c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9a83c_row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_9a83c_row4_col1" class="data row4 col1" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_9a83c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9a83c_row5_col0" class="data row5 col0" >7</td>
#                         <td id="T_9a83c_row5_col1" class="data row5 col1" >50</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_2bb77_" style='display:inline'><caption>One-to-many</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2bb77_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2bb77_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_2bb77_row0_col1" class="data row0 col1" >Jon Smith</td>
#                         <td id="T_2bb77_row0_col2" class="data row0 col2" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_2bb77_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2bb77_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_2bb77_row1_col1" class="data row1 col1" >Jon Smith</td>
#                         <td id="T_2bb77_row1_col2" class="data row1 col2" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_2bb77_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2bb77_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_2bb77_row2_col1" class="data row2 col1" >Sarah Adams</td>
#                         <td id="T_2bb77_row2_col2" class="data row2 col2" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_2bb77_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2bb77_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_2bb77_row3_col1" class="data row3 col1" >Maria Lopez</td>
#                         <td id="T_2bb77_row3_col2" class="data row3 col2" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_2bb77_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2bb77_row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_2bb77_row4_col1" class="data row4 col1" >Maria Lopez</td>
#                         <td id="T_2bb77_row4_col2" class="data row4 col2" >70</td>
#             </tr>
#     </tbody></table>

# %%
cur.close()
conn.close()
